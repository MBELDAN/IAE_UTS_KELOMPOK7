# %%
import requests

url = "https://sportapi7.p.rapidapi.com/api/v1/transfer"

headers = {
	"X-RapidAPI-Key": "eea92a9621mshbb5f39383ef16f2p147c78jsn3b2a2ac99577",
	"X-RapidAPI-Host": "sportapi7.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'transfers': [{'player': {'name': 'Claudio Echeverri', 'slug': 'claudio-echeverri', 'shortName': 'C. Echeverri', 'userCount': 8382, 'id': 1482424}, 'transferFrom': {'name': 'River Plate', 'slug': 'river-plate', 'shortName': 'River Plate', 'userCount': 0, 'type': 0, 'id': 3211, 'teamColors': {'primary': '#52b030', 'secondary': '#52b030', 'text': '#ffffff'}, 'fieldTranslations': {'nameTranslation': {'ru': 'Ривер Плейт'}, 'shortNameTranslation': {}}}, 'transferTo': {'name': 'Manchester City', 'slug': 'manchester-city', 'shortName': 'Manchester City', 'userCount': 0, 'type': 0, 'id': 17, 'teamColors': {'primary': '#52b030', 'secondary': '#52b030', 'text': '#ffffff'}, 'fieldTranslations': {'nameTranslation': {'ar': 'مانشستر سيتي', 'ru': 'Манчестер Сити'}, 'shortNameTranslation': {}}}, 'fromTeamName': 'River Plate', 'toTeamName': 'Manchester City', 'type': 2, 'transferFee': 0, 'transferFeeDescription': '-', 'id': 1975670, 'transferDateTimestamp': 1735603200, 'transferFeeRaw': {'value': 0, 'currency': 'EUR'}}, {'player': {'name': 'Marquinhos', 'slug': 'marquinhos', 'shortName': 'Marquinhos', 'userCount': 4668, 'id': 1116954, 'fieldTranslations': {'nameTranslation': {'ar': 'ماركينيوس'}, 'shortNameTranslation': {'ar': 'ماركينيوس'}}}, 'transferFrom': {'name': 'Fluminense', 'slug': 'fluminense', 'shortName': 'Fluminense', 'userCount': 0, 'type': 0, 'id': 1961, 'teamColors': {'primary': '#52b030', 'secondary': '#52b030', 'text': '#ffffff'}, 'fieldTranslations': {'nameTranslation': {'ru': 'Флуминенсе'}, 'shortNameTranslation': {}}}, 'transferTo': {'name': 'Arsenal', 'slug': 'arsenal', 'shortName': 'Arsenal', 'userCount': 0, 'type': 0, 'id': 42, 'teamColors': {'primary': '#52b030', 'secondary': '#52b030', 'text': '#ffffff'}, 'fieldTranslations': {'nameTranslation': {'ar': 'أرسنال', 'ru': 'Арсенал'}, 'shortNameTranslation': {}}}, 'fromTeamName': 'Fluminense', 'toTeamName': 'Arsenal', 'type': 2, 'transferFee': 0, 'transferFeeDescription': '-', 'id': 1995103, 'transferDateTimestamp': 1735603200, 'transferFeeRaw': {'value': 0, 'currency': 'EUR'}}, {'player': {'name': 'Yeferson Soteldo', 'slug': 'yeferson-soteldo', 'shortName': 'Y. Soteldo', 'userCount': 4119, 'id': 789960, 'fieldTranslations': {'nameTranslation': {'ar': 'جيفرسون سوتيلدو'}, 'shortNameTranslation': {'ar': 'ج. سوتيلدو'}}}, 'transferFrom': {'name': 'Grêmio', 'slug': 'gremio', 'shortName': 'Grêmio', 'userCount': 0, 'type': 0, 'id': 5926, 'teamColors': {'primary': '#52b030', 'secondary': '#52b030', 'text': '#ffffff'}, 'fieldTranslations': {'nameTranslation': {'ru': 'Гремио'}, 'shortNameTranslation': {}}}, 'transferTo': {'name': 'Santos', 'slug': 'santos', 'shortName': 'Santos', 'userCount': 0, 'type': 0, 'id': 1968, 'teamColors': {'primary': '#52b030', 'secondary': '#52b030', 'text': '#ffffff'}, 'fieldTranslations': {'nameTranslation': {'ru': 'ФК Сантос'}, 'shortNameTranslation': {}}}, 'fromTeamName': 'Grêmio', 'toTeamName': 'Santos', 'type': 2, 'transferFee': 0, 'transferFeeDescription': '-', 'id': 1964804, 'transferDateTimestamp': 1735603200, 'transferFeeRaw': {'value': 0, 'currency': 'EUR'}}, {'player': {'name': 'Gabriel Veron', 'slug': 'gabriel-veron', 'shortName': 'G. Veron', 'userCount': 2772, 'id': 1002819, 'fieldTranslations': {'nameTranslation': {'ar': 'جابرييل فيرون'}, 'shortNameTranslation': {'ar': 'ج. فيرون'}}}, 'transferFrom': {'name': 'Cruzeiro', 'slug': 'cruzeiro', 'shortName': 'Cruzeiro', 'userCount': 0, 'type': 0, 'id': 1954, 'teamColors': {'primary': '#52b030', 'secondary': '#52b030', 'text': '#ffffff'}, 'fieldTranslations': {'nameTranslation': {'ru': 'Крузейро'}, 'shortNameTranslation': {}}}, 'transferTo': {'name': 'FC Porto', 'slug': 'fc-porto', 'shortName': 'FC Porto', 'userCount': 0, 'type': 0, 'id': 3002, 'teamColors': {'primary': '#52b030', 'secondary': '#52b030', 'text': '#ffffff'}, 'fieldTranslations': {'nameTranslation': {'ar': 'اف سي بورتو', 'ru': 'Порту'}, 'shortNameTranslation': {}}}, 'fromTeamName': 'Cruzeiro', 'toTeamName': 'FC Porto', 'type': 2, 'tra ...
